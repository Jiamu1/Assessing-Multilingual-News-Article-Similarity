# %% [markdown]
# # Setup

# %%
import numpy as np 
from google.colab import drive
import os
import csv
import pandas as pd

# %%
drive.mount('/content/drive')
FOLDERNAME = 'ColabNotebooks/263/263 Final Project/Data'
# %cd drive/My\ Drive
# %cd $FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content/drive/My Drive/ColabNotebooks/263/263 Final Project/Data

# %%
# Training 
df_eval = pd.read_csv("semeval-2022_task8_train-data_batch (1).csv")

# %%
df_eval.head(1)

# %%
len(df_eval)
# Out:
# 4964

# %% [markdown]
# # Extract text

# %% [markdown]
# ## Functions

# %%
import requests
from bs4 import BeautifulSoup

# %%
def extract_text_from_url(url):
    # Make a request to the website
    response = requests.get(url)
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser', from_encoding='utf-8')
    
    # Find the main content of the page. This will depend on the structure of the webpage,
    # but often the text is inside <p> elements.
    paragraphs = soup.find_all('p')

    # Combine all the paragraphs into one string.
    text = ' '.join([p.get_text() for p in paragraphs])

    return text

# %%
def safe_extract_text_from_url(url):
    try:
        return extract_text_from_url(url)
    except Exception as e:
        print(f"Error extracting text from {url}: {e}")
        return None

# %% [markdown]
# ## Train

# %% [markdown]
# ### 0-1000

# %%
eval_text1 = []

# %%
# 0-500
eval_text_0_500 = []
for i in df_eval['ia_link1'][:500]:
  eval_text_0_500.append(safe_extract_text_from_url(i))
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py:226: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# Error extracting text from https://web.archive.org/web/www.latimes.com/california/story/2019-12-31/southern-california-precipitation-above-normal-year-end: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/www.latimes.com/california/story/2019-12-31/southern-california-precipitation-above-normal-year-end (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa90a0331f0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# ...

# %%
eval_text1 = list(eval_text1 + eval_text_0_500)

# Open (or create) a CSV file and write the list into it
with open('eval_text1.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(eval_text1)  # Use writerow for a single list (1D)

# %%
# 500-1000
eval_text_500_1000 = []
for i in df_eval['ia_link1'][500:1000]:
  eval_text_500_1000.append(safe_extract_text_from_url(i))
# Out:
# Error extracting text from https://web.archive.org/web/www.cbc.ca/news/canada/calgary/calgary-couple-liquor-store-thefts-whiskey-scotch-1.5411896?cmp=rss: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/www.cbc.ca/news/canada/calgary/calgary-couple-liquor-store-thefts-whiskey-scotch-1.5411896?cmp=rss (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa835c3a5f0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error extracting text from https://web.archive.org/web/www.couriermail.com.au/entertainment/celebrity/this-is-how-the-stars-said-hello-to-2020/news-story/f85b8214ea0b3850b4d6427dffa43cce: Exceeded 30 redirects.

# %%
eval_text1 = list(eval_text1 + eval_text_500_1000)

# Open (or create) a CSV file and write the list into it
with open('eval_text1.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(eval_text1)  # Use writerow for a single list (1D)

# %% [markdown]
# ### 1000-2000

# %%
# 1000-1500
eval_text_1000_1500 = []
for i in df_eval['ia_link1'][1000:1500]:
  eval_text_1000_1500.append(safe_extract_text_from_url(i))

# %%
eval_text1 = list(eval_text1 + eval_text_1000_1500)

# Open (or create) a CSV file and write the list into it
with open('eval_text1.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(eval_text1)  # Use writerow for a single list (1D)

# %%
# 1500-2000
eval_text_1500_2000 = []
for i in df_eval['ia_link1'][1500:2000]:
  eval_text_1500_2000.append(safe_extract_text_from_url(i))
# Out:
# Error extracting text from https://web.archive.org/web/www.telemundo47.com/historias-destacadas/tension-tras-ataques-a-embajada-cuales-son-las-duras-opciones-de-trump/2010729/: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/www.telemundo47.com/historias-destacadas/tension-tras-ataques-a-embajada-cuales-son-las-duras-opciones-de-trump/2010729/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa8355f92d0>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %%
eval_text1 = list(eval_text1 + eval_text_1500_2000)

# Open (or create) a CSV file and write the list into it
with open('eval_text1.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(eval_text1)  # Use writerow for a single list (1D)

# %% [markdown]
# ### 2000-3000

# %%
# 2000-2500
eval_text_2000_2500 = []
for i in df_eval['ia_link1'][2000:2500]:
  eval_text_2000_2500.append(safe_extract_text_from_url(i))
# Out:
# Error extracting text from https://web.archive.org/web/launion.com.ar/los-bomberos-de-lomas-ayudaron-a-combatir-un-voraz-incendio-en-un-frigorifico-de-general-las-heras/: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/launion.com.ar/los-bomberos-de-lomas-ayudaron-a-combatir-un-voraz-incendio-en-un-frigorifico-de-general-las-heras/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa835d5d8d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# ...

# %%
eval_text1 = list(eval_text1 + eval_text_2000_2500)

# Open (or create) a CSV file and write the list into it
with open('eval_text1.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(eval_text1)  # Use writerow for a single list (1D)

# %%
# 2500-3000
eval_text_2500_3000 = []
for i in df_eval['ia_link1'][2500:3000]:
  eval_text_2500_3000.append(safe_extract_text_from_url(i))
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py:226: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# Error extracting text from https://web.archive.org/web/www.handelsblatt.com/politik/deutschland/industriepolitik-altmaier-will-rohstoffe-sichern/25431418.html: Exceeded 30 redirects.
# Error extracting text from https://web.archive.org/web/www.presseportal.de/blaulicht/pm/11554/4482795: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
eval_text1 = list(eval_text1 + eval_text_2500_3000)

# Open (or create) a CSV file and write the list into it
with open('eval_text1.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(eval_text1)  # Use writerow for a single list (1D)

# %% [markdown]
# ### 3000-4000

# %%
# 3000-3500
eval_text_3000_3500 = []
for i in df_eval['ia_link1'][3000:3500]:
  eval_text_3000_3500.append(safe_extract_text_from_url(i))

# %%
eval_text1 = list(eval_text1 + eval_text_3000_3500)

# Open (or create) a CSV file and write the list into it
with open('eval_text1.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(eval_text1)  # Use writerow for a single list (1D)

# %%
# 3500-4000
eval_text_3500_4000 = []
for i in df_eval['ia_link1'][3500:4000]:
  eval_text_3500_4000.append(safe_extract_text_from_url(i))
# Out:
# Error extracting text from https://web.archive.org/web/haberport.com/gundem/bolu-daki-karantina-yurdunda-skandal-goruntuler-savcilik-sorusturma-h33214.html: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error extracting text from https://web.archive.org/web/www.sondakika.com/haber-biz-bize-yeteriz-turkiyem-kampanyasina-destekler-13088183/: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Error extracting text from https://web.archive.org/web/de.sputniknews.com/panorama/20200310326569665-netrebko-coronavirus-meinung/: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/de.sputniknews.com/panorama/20200310326569665-netrebko-coronavirus-meinung/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f5ac0f1c070>: Failed to establish a new connection: [Errno 111] Connection refused'))
# ...

# %%
eval_text1 = list(eval_text1 + eval_text_3500_4000)

# Open (or create) a CSV file and write the list into it
with open('eval_text1.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(eval_text1)  # Use writerow for a single list (1D)

# %% [markdown]
# ### 4000-5000

# %%
# 4000-4500
eval_text_4000_4500 = []
for i in df_eval['ia_link1'][4000:4500]:
  eval_text_4000_4500.append(safe_extract_text_from_url(i))
# Out:
# Error extracting text from https://web.archive.org/web/www.finanznachrichten.de/nachrichten-2020-05/49712546-dgap-hv-erwe-immobilien-ag-bekanntmachung-der-3-015.htm: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error extracting text from https://web.archive.org/web/www.wn.de/NRW/4189103-Recht-Millionenstreit-nach-Orkan-Kyrill-Klausner-zieht-vor-BGH?utm_source=RSS: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/www.wn.de/NRW/4189103-Recht-Millionenstreit-nach-Orkan-Kyrill-Klausner-zieht-vor-BGH?utm_source=RSS (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f5ac1c18130>: Failed to establish a new connection: [Errno 111] Connection refused'))
# ...

# %%
eval_text1 = list(eval_text1 + eval_text_4000_4500)

# Open (or create) a CSV file and write the list into it
with open('eval_text1.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(eval_text1)  # Use writerow for a single list (1D)

# %%
# 4500-5000
eval_text_4500_5000 = []
for i in df_eval['ia_link1'][4500:]:
  eval_text_4500_5000.append(safe_extract_text_from_url(i))

# %%
eval_text1 = list(eval_text1 + eval_text_4500_5000)

# Open (or create) a CSV file and write the list into it
with open('eval_text1.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(eval_text1)  # Use writerow for a single list (1D)

# %%
len(eval_text1)
# Out:
# 4964

# %%
len(df_eval)
# Out:
# 4964

# %% [markdown]
# # Merge to dataframe

# %%
eval_text1 = pd.read_csv("eval_text1.csv")

# %%
eval_text1

# %%
c = eval_text1.columns.tolist()
len(c)

# %%
df_eval['text1'] = c

# %%
df_eval['text1'] = eval_text1

# %%
t2 = pd.read_csv('train_text2_data.csv')

# %%
c2 = t2.columns.tolist()
len(c2)
# Out:
# 4964

# %%
df_eval['text2'] = c2

# %%
df_eval.head(2)
# Out:
#   url1_lang url2_lang                pair_id  \
# 0        en        en  1484084337_1484110209
# 1        en        en  1484396422_1483924666
#
#                                                link1  \
# 0  https://www.washingtonpost.com/local/virginia-...
# 1  https://www.stlucianewsonline.com/guyana-three...
#
#                                                link2  \
# 0  https://www.washingtonpost.com/world/the_ameri...
# 1  https://www.thestar.com/news/world/europe/2020...
#
#                                             ia_link1  \
# 0  https://web.archive.org/web/www.washingtonpost...
# 1  https://web.archive.org/web/www.stlucianewsonl...
#
#                                             ia_link2  Geography  Entities  \
# 0  https://web.archive.org/web/www.washingtonpost...        4.0       4.0
# 1  https://web.archive.org/web/www.thestar.com/ne...        4.0       4.0
#
#    Time  Narrative   Overall     Style      Tone  \
# 0   1.0        4.0  4.000000  1.666667  2.000000
# ...

# %%
df_eval.to_csv('train_df.csv', index=False)

# %% [markdown]
# # Remove Nones

# %%
df_eval = df_eval.dropna()

# %%
len(df_eval)
# Out:
# 4955

# %%
df_eval.to_csv('train_df.csv', index=False)
